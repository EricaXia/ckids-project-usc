# %% [markdown]
# ## Exploratory Data Analysis of 2020 Instagram Data

# %% [markdown]
# Enter this in developer console to avoid runtime timeout:
# > function ClickConnect(){
# console.log("Connnect Clicked - Start");
# document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
# console.log("Connnect Clicked - End");
# };
# setInterval(ClickConnect, 60000)

# %%
# import libraries
import os
import sys

import pandas as pd
import numpy as np
import scipy as sp

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import random
import time

# %%
# set current working directory to whereever the tagged data's stored (ie: the csv files)
os.chdir("/content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags")

# %%
df1 = pd.read_csv('df_kale.csv', index_col=0)
df2 = pd.read_csv('df_fries.csv', index_col=0)

# %%
## Merge all food hashtag dfs and get some initial information

# %%
df_ig = df1.append(df2, ignore_index=True)   # can do multiple df appends eg "df1.append([df2,df3,df4],ignore_index=True)"

# %%
df_ig.shape
# Out:
# (1723, 53)

# %%
df_ig.describe()
# Out:
#                  id  taken_at_timestamp  ...  encoding_status  video_duration
# count  1.717000e+03        1.717000e+03  ...              0.0      147.000000
# mean   2.256542e+18        1.583221e+09  ...              NaN       28.763932
# std    4.021722e+16        4.794262e+06  ...              NaN       42.139213
# min    1.006416e+18        1.434194e+09  ...              NaN        1.000000
# 25%    2.256124e+18        1.583171e+09  ...              NaN        9.766000
# 50%    2.261141e+18        1.583769e+09  ...              NaN       17.800000
# 75%    2.261288e+18        1.583787e+09  ...              NaN       35.416000
# max    2.262094e+18        1.583883e+09  ...              NaN      418.983000
#
# [8 rows x 8 columns]

# %%
df_ig.info()

# %%
df_ig.head(3)
# Out:
#                  file_name  ...                                      location_desc
# 0  2020-03-09_15-23-42_UTC  ...                                                NaN
# 1  2020-03-09_15-24-07_UTC  ...                                                NaN
# 2  2020-03-09_15-24-51_UTC  ...  Siirt Kale\nhttps://maps.google.com/maps?q=37....
#
# [3 rows x 53 columns]

# %% [markdown]
# # TODO:
# - filter out a new df with locations that are NON NaN
# - calculate top 5 outlets
# - visualize in a pretty graph
# - finish df processing for rest of hashtags and rerun notebook with those included
# - see A's note and last yr's slides for what other initial stats to look at
