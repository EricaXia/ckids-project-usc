# %% [markdown]
# Multi users in one notebook - test

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags
# /content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags

# %%
# !pip install instaloader==4.3a2
# Out:
# ...
#   Created wheel for instaloader: filename=instaloader-4.3a2-cp36-none-any.whl size=42576 sha256=8ffdbf51cd68a68b764ab66fdee452d4f083ded759ace3541872aadcc2a59851
#   Stored in directory: /root/.cache/pip/wheels/c1/3b/d8/55829f0c32976d2153b9c61a82bd291a1dfdb5e3d9b716139c
# Successfully built instaloader
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import instaloader
print(instaloader.__version__)
# Out:
# 4.3a2

# %%
TAGS_food_id = '1ZHVkZ5upNhI6yfZZtrz1EXiv2XzVTVxq'
TAGS_nonfood_id = '1xNeJRpX8KCDuKkFeX9_GkoahicbLxh0s'
# Downloading tags list

downloaded1 = drive.CreateFile({'id':TAGS_food_id})
# print('Downloaded content:', downloaded1.GetContentString())

downloaded2 = drive.CreateFile({'id':TAGS_nonfood_id})
# print('Downloaded content:', downloaded2.GetContentString())

# %%
print(type(downloaded1.GetContentString()))
food_tags = downloaded1.GetContentString().strip().split()
print(food_tags)
# Out:
# <class 'str'>
# ['Burger', 'Salad', 'fries', 'smoothie', 'kale']

# %%
nonfood_tags = downloaded2.GetContentString().strip().split()
print(nonfood_tags)
# Out:
# ['foodporn', 'foodie', 'instafood', 'foodpics', 'foodgasm', 'foodoftheday', 'recipe', 'cleaneating', 'foodinspiration']

# %% [markdown]
# ## Initial test scrape

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags
# /content/drive/My Drive/Colab Notebooks/CKIDS_main/data/food_tags

# %%
from time import sleep

# %%
# ACCOUNT 1


L = instaloader.Instaloader(download_videos=False,
                            max_connection_attempts=3, 
                            request_timeout=120)  

L.login('musketeers1128@gmail.com', 'EvOu7CR7Iq2V')


for h in food_tags[-2:]:
    L.download_hashtag(h, max_count=10_000,
                       fast_update=False)
    sleep(360)
# Out:
# Retrieving pictures with hashtag smoothie...
# [  1] #smoothie #smoothie/2020-03-08_19-19-15_UTC.jpg [Protein is the macronutrient …] json
# [  2] #smoothie #smoothie/2020-03-08_19-18-41_UTC.jpg [Why wait in line at the juice…] json
# [  3] #smoothie #smoothie/2020-03-08_19-18-11_UTC.jpg [Healthy Hydrated & High @trip…] json
# [  4] #smoothie #smoothie/2020-03-08_19-17-18_UTC.jpg [#smoothie #vihreäävoimaa #gre…] json
# [  5] #smoothie #smoothie/2020-03-08_19-16-57_UTC.jpg [Happy #InternationalWomensDay…] geo comments json
# [  6] #smoothie #smoothie/2020-03-08_19-16-26_UTC.jpg [Fresh Strawberries+Pineapples…] json
# [  7] #smoothie #smoothie/2020-03-08_19-16-12_UTC.jpg [BERRY BEAUTIFUL SMOOTHIE BOWL…] geo comments json
# [  8] #smoothie #smoothie/2020-03-08_19-16-06_UTC_1.jpg #smoothie/2020-03-08_19-16-06_UTC_2.jpg #smoothie/2020-03-08_19-16-06_UTC_3.jpg [Ya sea que escogas smoothie d…] json
# ...

# %%
# ACCOUNT 2

L = instaloader.Instaloader(download_videos=False,
                            max_connection_attempts=3, 
                            request_timeout=120)  

L.login('sunwisdom101@gmail.com', 'EvOu7CR7Iq2V')


for h in food_tags[-4:-2]
    L.download_hashtag(h, max_count=10_000,
                       fast_update=False)
    sleep(360)

# %%
# # !mkdir "/content/drive/My Drive/Colab Notebooks/CKIDS_main/data/nonfood_tags"
# %cd "/content/drive/My Drive/Colab Notebooks/CKIDS_main/data/nonfood_tags"
# !pwd

# for h in nonfood_tags:
#     L.download_hashtag(h, max_count=250000)

# %% [markdown]
# Next step: selectively scrap by one week (or filter out existing dled posts within a one week time span)
